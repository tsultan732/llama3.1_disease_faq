# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from datasets import load_dataset

# %%
aug_dataset = load_dataset('json', data_files="/content/drive/MyDrive/Llama3.1FineTuning/Diesease FAQS/augmented_dataset.json", split="train")
aug_dataset

# %%
# Convert to Pandas DataFrames
df_dataset = pd.DataFrame(dataset)
df_aug_dataset = pd.DataFrame(aug_dataset)

# Perform the set difference
df_difference = pd.concat([df_aug_dataset, df_dataset]).drop_duplicates(keep=False)

# Save the filtered DataFrame as a JSON file
output_file_path = '/content/drive/MyDrive/Llama3.1FineTuning/Diesease FAQS/aug_dataset_filtered.json'
df_difference.to_json(output_file_path, orient='records', lines=True)
